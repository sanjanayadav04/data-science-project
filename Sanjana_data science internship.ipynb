# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#1. Fashion-MNIST
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()
#2. To analyze data 
X_train_full = X_train_full / 255.0
X_test = X_test / 255.0
#clothes name
class_names = ["T-shirt/Top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]
plt.figure(figsize=(10,5))
for i in range (10):
    plt.subplot(2,5,i+1)
    plt.imshow(X_train_full[i],cmap='gray')
    plt.title(class_names[y_train_full[i]])
    plt.tight_layout()
    plt.show()
 
+

print("Data is successfully loaded")
print("Shape of training data:", X_train_full.shape)
# Out:
# Data is successfully loaded
# Shape of training data: (60000, 28, 28)

# %%
#3. Neural network (Model)
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(50, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
])
#compile model
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])
#4. model ko 10 epochs
history = model.fit(X_train_full, y_train_full, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8168 - loss: 0.5071 - val_accuracy: 0.8498 - val_loss: 0.4112
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8611 - loss: 0.3767 - val_accuracy: 0.8621 - val_loss: 0.3823
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8746 - loss: 0.3407 - val_accuracy: 0.8720 - val_loss: 0.3540
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8825 - loss: 0.3160 - val_accuracy: 0.8738 - val_loss: 0.3422
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8896 - loss: 0.2954 - val_accuracy: 0.8838 - val_loss: 0.3229
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8964 - loss: 0.2778 - val_accuracy: 0.8806 - val_loss: 0.3358
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8999 - loss: 0.2670 - val_accuracy: 0.8788 - val_loss: 0.3454
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9037 - loss: 0.2553 - val_accuracy: 0.8832 - val_loss: 0.3355
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9082 - loss: 0.2431 - val_accuracy: 0.8802 - val_loss: 0.3864
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9121 - loss: 0.2333 - val_accuracy: 0.8928 - val_loss: 0.3063

# %%
#5. graph plot
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.title("trainning and validation work")
plt.show()

# %%
#7 dropout
model_dropout = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="relu"),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(50, activation="relu"),
    keras.layers.Dense(10, activation="softmax"),
])

model_dropout.compile(loss="sparse_categorical_crossentropy",
                      optimizer="adam",
                      metrics=["accuracy"])

history_dropout = model_dropout.fit(X_train_full, y_train_full, epochs=10, validation_split=0.2)
# Out:
# C:\Users\princ\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7668 - loss: 0.6350 - val_accuracy: 0.8335 - val_loss: 0.4542
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8336 - loss: 0.4624 - val_accuracy: 0.8602 - val_loss: 0.3903
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8484 - loss: 0.4196 - val_accuracy: 0.8613 - val_loss: 0.3842
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8570 - loss: 0.3952 - val_accuracy: 0.8728 - val_loss: 0.3561
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8626 - loss: 0.3771 - val_accuracy: 0.8726 - val_loss: 0.3463
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8649 - loss: 0.3675 - val_accuracy: 0.8719 - val_loss: 0.3460
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8706 - loss: 0.3519 - val_accuracy: 0.8735 - val_loss: 0.3486
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8725 - loss: 0.3449 - val_accuracy: 0.8815 - val_loss: 0.3346
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8763 - loss: 0.3384 - val_accuracy: 0.8800 - val_loss: 0.3369
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8788 - loss: 0.3292 - val_accuracy: 0.8831 - val_loss: 0.3251

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred_all = np.argmax(model.predict(X_test), axis=-1)

cm = confusion_matrix(y_test, y_pred_all)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('Actual (correct answer)')
plt.xlabel('predicted (model answer)')
plt.title("confusion matrix")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
X_new = X_test[:10]
y_proba = model.predict(X_new)
y_pred = np.argmax(y_proba, axis=-1)
print("prediction of model: ", [class_names[i] for i in y_pred])
print("real (right) kapra:", [class_names[i] for i in y_test[:10]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# prediction of model:  ['Ankle Boot', 'Pullover', 'Trouser', 'Trouser', 'Shirt', 'Trouser', 'Coat', 'Shirt', 'Sandal', 'Sneaker']
# real (right) kapra: ['Ankle Boot', 'Pullover', 'Trouser', 'Trouser', 'Shirt', 'Trouser', 'Coat', 'Shirt', 'Sandal', 'Sneaker']
